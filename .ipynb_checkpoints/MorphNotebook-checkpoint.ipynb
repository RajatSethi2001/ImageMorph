# %%
import cv2
import numpy as np
import tensorflow as tf
from MorphEnv import MorphEnv
from os.path import exists
from tensorflow.keras import datasets, layers, models
from stable_baselines3 import PPO, TD3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.noise import NormalActionNoise

model_victim = models.load_model('mnist')

img = cv2.resize(cv2.imread("Original.png", 0), (36, 36)).reshape(36, 36, 1)
img_label = 7
outcome = 5

env = MorphEnv(model_victim, img, img_label, outcome)
model_name = "MorphPPO.zip"

policy_name = "CnnPolicy"
n_timesteps = 1000
n_steps = 128

model_attack = PPO(policy_name, env, n_steps=n_steps, verbose=0)

done = False
while not done:
    model_attack.learn(n_timesteps, verbose=0)
    model_attack.save(model_name)
    keep_training = input("Do you want to continue? [Y/N]: ")
    if keep_training not in "yY":
        done = True
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# /mnt/c/Users/rajat/Desktop/RLProjects/RLImageMorph/MorphEnv.py:40: RuntimeWarning: overflow encountered in ubyte_scalars
#   euclid_distance += ((self.img_perturb[row][col][pixel] - self.img_original[row][col][pixel]) / 255.0) ** 2
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-756e0051243d> in <module>
#      26 done = False
#      27 while not done:
# ---> 28     model_attack.learn(n_timesteps)
#      29     model_attack.save(model_name)
#      30     keep_training = input("Do you want to continue? [Y/N]: ")
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     315     ) -> PPOSelf:
#     316
# --> 317         return super().learn(
#     318             total_timesteps=total_timesteps,
#     319             callback=callback,
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     260         while self.num_timesteps < total_timesteps:
#     261
# --> 262             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     263
#     264             if continue_training is False:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     179                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     180
# --> 181             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     182
#     183             self.num_timesteps += env.num_envs
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      41     def step_wait(self) -> VecEnvStepReturn:
#      42         for env_idx in range(self.num_envs):
# ---> 43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44                 self.actions[env_idx]
#      45             )
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/monitor.py in step(self, action)
#      92         if self.needs_reset:
#      93             raise RuntimeError("Tried to step environment that needs reset")
# ---> 94         observation, reward, done, info = self.env.step(action)
#      95         self.rewards.append(reward)
#      96         if done:
#
# /mnt/c/Users/rajat/Desktop/RLProjects/RLImageMorph/MorphEnv.py in step(self, action)
#      31         perturbance = self.results[self.outcome]
#      32
# ---> 33         self.render()
#      34
#      35         euclid_distance = 0
#
# /mnt/c/Users/rajat/Desktop/RLProjects/RLImageMorph/MorphEnv.py in render(self)
#      59         plt.subplot(1,2,1)
#      60         self.plot_image(self.results, self.img_label, self.outcome, img_display)
# ---> 61         plt.subplot(1,2,2)
#      62         self.plot_value_array(self.results, self.img_label, self.outcome)
#      63         plt.show()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1267     else:
#    1268         # we have exhausted the known Axes and none match, make a new one!
# -> 1269         ax = fig.add_subplot(*args, **kwargs)
#    1270
#    1271     fig.sca(ax)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     743             projection_class, pkw = self._process_projection_requirements(
#     744                 *args, **kwargs)
# --> 745             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     746             key = (projection_class, pkw)
#     747         return self._add_axes_internal(ax, key)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     643
#     644         # this call may differ for non-sep axes, e.g., polar
# --> 645         self._init_axis()
#     646         if facecolor is None:
#     647             facecolor = mpl.rcParams['axes.facecolor']
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     775     def _init_axis(self):
#     776         # This is moved out of __init__ because non-separable axes don't use it
# --> 777         self.xaxis = maxis.XAxis(self)
#     778         self.spines.bottom.register_axis(self.xaxis)
#     779         self.spines.top.register_axis(self.xaxis)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#    2188
#    2189     def __init__(self, *args, **kwargs):
# -> 2190         super().__init__(*args, **kwargs)
#    2191         # x in axes coords, y in display coords (to be updated at draw time by
#    2192         # _update_label_positions and _update_offset_text_position).
#
# ~/.local/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     690         self._minor_tick_kw = dict()
#     691
# --> 692         self.clear()
#     693         self._autoscale_on = True
#     694
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in clear(self)
#     875         self.label.set_text('')  # self.set_label_text would change isDefault_
#     876
# --> 877         self._set_scale('linear')
#     878
#     879         # Clear the callback registry for this axis, or it may "leak"
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     774         else:
#     775             self._scale = value
# --> 776         self._scale.set_default_locators_and_formatters(self)
#     777
#     778         self.isDefault_majloc = True
#
# ~/.local/lib/python3.8/site-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#     103     def set_default_locators_and_formatters(self, axis):
#     104         # docstring inherited
# --> 105         axis.set_major_locator(AutoLocator())
#     106         axis.set_major_formatter(ScalarFormatter())
#     107         axis.set_minor_formatter(NullFormatter())
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axis.py in set_major_locator(self, locator)
#    1804             self.major.formatter._set_locator(locator)
#    1805         locator.set_axis(self)
# -> 1806         self.stale = True
#    1807
#    1808     def set_minor_locator(self, locator):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/artist.py in stale(self, val)
#     298
#     299         if val and self.stale_callback is not None:
# --> 300             self.stale_callback(self, val)
#     301
#     302     def get_window_extent(self, renderer=None):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/artist.py in _stale_axes_callback(self, val)
#      81
#      82 def _stale_axes_callback(self, val):
# ---> 83     if self.axes:
#      84         self.axes.stale = val
#      85
#
# ~/.local/lib/python3.8/site-packages/matplotlib/artist.py in axes(self)
#     263         return ax.yaxis.convert_units(y)
#     264
# --> 265     @property
#     266     def axes(self):
#     267         """The `~.axes.Axes` instance the artist resides in, or *None*."""
#
# KeyboardInterrupt:
